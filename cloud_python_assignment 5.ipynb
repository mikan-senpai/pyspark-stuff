# %%
#1. Read csv data provided
import pandas as pd
df=pd.read_csv("Work_data.csv")

# %%
df
# Out:
#     Index          User Id First Name  Last Name  Gender  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
# 2. Calculate statistics
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
# 3. Create a scatter plot graph
#jobtitle vs gender
import matplotlib.pyplot as plt
plt.scatter(df['Job Title'], df['Gender'], color='blue')
plt.xlabel('job Title')
plt.ylabel('Gender')
plt.title('Scatter plot')
plt.show()

# %%
# 3. Create a scatter plot graph
#jobtitle vs date of birth
import matplotlib.pyplot as plt
plt.scatter(df['Job Title'], df['Date of birth'], color='blue')
plt.xlabel('job Title')
plt.ylabel('Date of birth')
plt.title('Scatter plot')
plt.show()

# %%
from datetime import datetime
def calculate_age(dob):
    today=datetime.today()
    date=datetime.strptime(dob, '%m/%d/%Y')
    age=today.year-date.year-((today.month, today.day)<(date.month, date.day))
    return age

# %%
df['age']=df['Date of birth'].apply(calculate_age)

# %%
df
# Out:
#     Index          User Id First Name  Last Name  Gender  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    10/26/1945
# 1        bethany14@example.com       214.112.6044x4913     3/24/1910
# 2        bthompson@example.com            277.609.7938      7/2/1992
# ...

# %%
# 3. Create a scatter plot graph
#age vs jobtitle
import matplotlib.pyplot as plt
plt.scatter(df['age'], df['Job Title'], color='blue')
plt.xlabel('age')
plt.ylabel('Job Title')
plt.title('Scatter plot')
plt.show()
